# %% [markdown]
# # Create and evaluate handcrafted classification rules in decision-rules
#
# In this tutorial we will create and evaluate decision rules for regression.

# %% [markdown]
# First, we load our data from the file bolts.csv. The dataset has numeric columns named RUN, SPEED1, TOTAL, SPEED2, NUMBER2, SENS, TIME and a countinuous target column named class.

# %%
import pandas as pd
IRIS_PATH = 'resources/regression/bolts.csv'
bolts_df = pd.read_csv(IRIS_PATH)
display(bolts_df)
print('Columns: ', bolts_df.columns.values)
print('Histogram of class')
_ = bolts_df['class'].hist()
pd.plotting.scatter_matrix(bolts_df)
# Out:
#      RUN  SPEED1  TOTAL  SPEED2  NUMBER2  SENS    TIME  class
# 0   13.0     2.0   30.0     2.5      0.0  10.0   22.39  14.93
# 1   11.0     6.0   30.0     1.5      2.0   0.0  109.10  72.73
# 2   19.0     6.0   10.0     1.5      2.0   6.0   39.74  79.48
# 3   16.0     2.0   10.0     2.5      2.0   6.0    9.22  18.44
# 4   24.0     2.0   10.0     1.5      0.0  10.0   17.56  35.12
# 5   28.0     2.0   30.0     1.5      2.0   6.0   18.54  12.36
# 6   25.0     2.0   10.0     1.5      0.0   6.0    5.70  11.40
# 7    3.0     4.0   20.0     2.0      1.0   8.0    9.39   9.39
# 8   31.0     6.0   10.0     2.5      0.0   6.0   28.89  57.78
# 9    2.0     2.0   10.0     1.5      2.0  10.0    8.39  16.78
# 10  21.0     2.0   30.0     2.5      2.0  10.0   30.12  20.08
# 11  10.0     6.0   30.0     2.5      2.0   6.0  106.46  70.97
# 12   6.0     6.0   30.0     2.5      0.0   6.0  100.43  66.95
# 13  26.0     6.0   30.0     1.5      2.0   6.0  111.66  74.44
# ...
